# %%
import pandas as pd 
import numpy as np 
from sklearn.model_selection import  train_test_split
from sklearn.preprocessing import OneHotEncoder

# %%
d = pd.read_csv('cars.csv')

# %%
d.sample(10)
# Out:
#          brand  km_driven    fuel         owner  selling_price
# 5789    Maruti      20000     CNG   First Owner         430000
# 3462   Hyundai     100000  Petrol  Second Owner         140000
# 3053    Maruti      15000  Petrol   First Owner         650000
# 5947     Honda      27233  Diesel   First Owner         465000
# 7368  Mahindra      10000  Diesel   First Owner        1450000
# 1171   Hyundai      31800  Petrol   First Owner         650000
# 6336    Maruti      65000  Petrol  Second Owner         250000
# 7701     Lexus      20000  Petrol   First Owner        5150000
# 4777  Mahindra      11500  Diesel   First Owner         819999
# 6855  Mahindra      19700  Petrol   First Owner         445000

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   brand          8128 non-null   object
#  1   km_driven      8128 non-null   int64
#  2   fuel           8128 non-null   object
#  3   owner          8128 non-null   object
#  4   selling_price  8128 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 317.6+ KB

# %%
d.value_counts('brand') # to count no of variable in a colmun
# Out:
# brand
# Maruti           2448
# Hyundai          1415
# Mahindra          772
# Tata              734
# Toyota            488
# Honda             467
# Ford              397
# Chevrolet         230
# Renault           228
# Volkswagen        186
# BMW               120
# Skoda             105
# Nissan             81
# Jaguar             71
# Volvo              67
# Datsun             65
# Mercedes-Benz      54
# Fiat               47
# Audi               40
# Lexus              34
# Jeep               31
# Mitsubishi         14
# Land                6
# Force               6
# Isuzu               5
# Kia                 4
# Ambassador          4
# MG                  3
# Daewoo              3
# Opel                1
# Peugeot             1
# Ashok               1
# Name: count, dtype: int64

# %%
d['brand'].nunique()
# Out:
# 32

# %%
d['fuel'].nunique()
# Out:
# 4

# %% [markdown]
# ### one hot encoding

# %%
pd.get_dummies(d,columns=['fuel','owner'])
# Out:
#         brand  km_driven  selling_price  fuel_CNG  fuel_Diesel  fuel_LPG  \
# 0      Maruti     145500         450000     False         True     False
# 1       Skoda     120000         370000     False         True     False
# 2       Honda     140000         158000     False        False     False
# 3     Hyundai     127000         225000     False         True     False
# 4      Maruti     120000         130000     False        False     False
# ...       ...        ...            ...       ...          ...       ...
# 8123  Hyundai     110000         320000     False        False     False
# 8124  Hyundai     119000         135000     False         True     False
# 8125   Maruti     120000         382000     False         True     False
# 8126     Tata      25000         290000     False         True     False
# 8127     Tata      25000         290000     False         True     False
#
#       fuel_Petrol  owner_First Owner  owner_Fourth & Above Owner  \
# ...

# %% [markdown]
# ### for doing k -1  one hot encoding

# %%
pd.get_dummies(d,columns=['fuel','owner'],drop_first=True)
# Out:
#         brand  km_driven  selling_price  fuel_Diesel  fuel_LPG  fuel_Petrol  \
# 0      Maruti     145500         450000         True     False        False
# 1       Skoda     120000         370000         True     False        False
# 2       Honda     140000         158000        False     False         True
# 3     Hyundai     127000         225000         True     False        False
# 4      Maruti     120000         130000        False     False         True
# ...       ...        ...            ...          ...       ...          ...
# 8123  Hyundai     110000         320000        False     False         True
# 8124  Hyundai     119000         135000         True     False        False
# 8125   Maruti     120000         382000         True     False        False
# 8126     Tata      25000         290000         True     False        False
# 8127     Tata      25000         290000         True     False        False
#
# ...

# %% [markdown]
# ### One HOt encoding using sklearn

# %%
xtrain, xtest , ytrain, ytest = train_test_split(d.iloc[:,0:4], d.iloc[:,-1], test_size=0.3,random_state=0)

# %%
xtrain
# Out:
#            brand  km_driven    fuel         owner
# 5224        Tata      20000  Petrol   First Owner
# 520       Maruti      30000  Petrol   First Owner
# 36        Maruti      15000  Petrol   First Owner
# 5782        Ford      53000  Diesel   First Owner
# 6522   Chevrolet     120000  Diesel   First Owner
# ...          ...        ...     ...           ...
# 4931        Tata      70000  Diesel   Third Owner
# 3264        Ford     100000  Diesel  Second Owner
# 1653     Hyundai      90000  Petrol  Second Owner
# 2607  Volkswagen      90000  Diesel   First Owner
# 2732     Hyundai     110000  Petrol   First Owner
#
# [5689 rows x 4 columns]

# %%
ohe = OneHotEncoder(drop='first', dtype=np.int32)

# %%
xtrainohe= ohe.fit_transform(xtrain[['fuel', 'owner']]).toarray()

# %%
xtestohe= ohe.fit_transform(xtest[['fuel', 'owner']]).toarray()

# %%
xtrainohe.shape
# Out:
# (5689, 7)

# %%
np.hstack((xtrain[['brand','km_driven']].values,xtrainohe))
# Out:
# array([['Tata', 20000, 0.0, ..., 0.0, 0.0, 0.0],
#        ['Maruti', 30000, 0.0, ..., 0.0, 0.0, 0.0],
#        ['Maruti', 15000, 0.0, ..., 0.0, 0.0, 0.0],
#        ...,
#        ['Hyundai', 90000, 0.0, ..., 1.0, 0.0, 0.0],
#        ['Volkswagen', 90000, 1.0, ..., 0.0, 0.0, 0.0],
#        ['Hyundai', 110000, 0.0, ..., 0.0, 0.0, 0.0]], dtype=object)

# %% [markdown]
# ### make categories

# %%
counts = d['brand'].value_counts()

# %%
d['brand'].nunique()
threshold = 100

# %%
rep = counts[counts<= threshold].index

# %%
pd.get_dummies(d['brand'].replace(rep,'N/A'))
# Out:
#         BMW  Chevrolet   Ford  Honda  Hyundai  Mahindra  Maruti    N/A  \
# 0     False      False  False  False    False     False    True  False
# 1     False      False  False  False    False     False   False  False
# 2     False      False  False   True    False     False   False  False
# 3     False      False  False  False     True     False   False  False
# 4     False      False  False  False    False     False    True  False
# ...     ...        ...    ...    ...      ...       ...     ...    ...
# 8123  False      False  False  False     True     False   False  False
# 8124  False      False  False  False     True     False   False  False
# 8125  False      False  False  False    False     False    True  False
# 8126  False      False  False  False    False     False   False  False
# 8127  False      False  False  False    False     False   False  False
#
#       Renault  Skoda   Tata  Toyota  Volkswagen
# 0       False  False  False   False       False
# ...

# %%
import tensorflow as tf
from tensorflow import keras

# %%
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

a = torch.randn(10000, 10000, device=device)
b = torch.randn(10000, 10000, device=device)

c = torch.matmul(a, b)

print("Matrix multiplication done.")
print(f"Result tensor device: {c.device}")
# Out:
# Using device: cpu
# Matrix multiplication done.
# Result tensor device: cpu

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

a = torch.randn(10000, 10000, device=device)
b = torch.randn(10000, 10000, device=device)

c = torch.matmul(a, b)

print("Matrix multiplication done.")
print(f"Result tensor device: {c.device}")
# Out:
# Using device: cuda
# Matrix multiplication done.
# Result tensor device: cuda:0

# %%
import torch

# Print total, reserved, and free memory in MB
print(f"Allocated memory: {torch.cuda.memory_allocated() / 1024 ** 2:.2f} MB")
print(f"Cached memory:   {torch.cuda.memory_reserved() / 1024 ** 2:.2f} MB")
# Out:
# Allocated memory: 1154.12 MB
# Cached memory:   1166.00 MB

# %%
import torch
print(torch.version.cuda)
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# 12.1
# True
# NVIDIA GeForce RTX 4050 Laptop GPU

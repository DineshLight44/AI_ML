# %%
import tensorflow as tf 
from tensorflow.keras import datasets,layers ,models
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_dir = r'D:\datasets\PlantVillage\train'
validation_dir = r'D:\datasets\PlantVillage\validation'

# %%
train_datagen = ImageDataGenerator(rescale=1./255)
validation_datagen = ImageDataGenerator(rescale=1./255)

# %%
traain_gen = train_datagen.flow_from_directory(
    train_dir,
    target_size=(150,150),
    batch_size=30,
    class_mode='categorical'
)
# Out:
# Found 16504 images belonging to 16 classes.

# %%
vali_generator = validation_datagen.flow_from_directory(
    validation_dir,
    target_size=(150,150,),
    batch_size=30,
    class_mode='categorical')
# Out:
# Found 4134 images belonging to 16 classes.

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)))
model.add(layers.MaxPool2D(2,2))
# Out:
# C:\Users\dkglt\anaconda3\envs\torch310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.add(layers.Conv2D(64,(3,3), activation='relu'))
model.add(layers.MaxPool2D(2,3))

# %%
model.add(layers.Conv2D(128,(3,3),activation='relu'))
model.add(layers.MaxPool2D(2,2))

# %%
model.add(layers.Flatten())
model.add(layers.Dense(256,activation='relu'))
model.add(layers.Dense(traain_gen.num_classes,activation='softmax'))

# %%
hist = model.compile(
    optimizer='adam',
    loss = 'categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model.fit(
    traain_gen,
    steps_per_epoch=len(traain_gen),
    epochs=10,validation_data=vali_generator, validation_steps=len(vali_generator)
)
# Out:
# Epoch 1/10
# C:\Users\dkglt\anaconda3\envs\torch310\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 85s 151ms/step - accuracy: 0.4881 - loss: 1.5776 - val_accuracy: 0.7864 - val_loss: 0.6262
# Epoch 2/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 80s 145ms/step - accuracy: 0.8465 - loss: 0.4558 - val_accuracy: 0.8907 - val_loss: 0.3240
# Epoch 3/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 80s 145ms/step - accuracy: 0.9185 - loss: 0.2467 - val_accuracy: 0.9119 - val_loss: 0.2618
# Epoch 4/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 80s 146ms/step - accuracy: 0.9545 - loss: 0.1366 - val_accuracy: 0.8660 - val_loss: 0.4539
# Epoch 5/10
# ...

# %%
model.save('PlantVillage_CNN_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

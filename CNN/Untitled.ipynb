# %%
import tensorflow as tf
from tensorflow.keras import datasets,layers ,models

# %%
(train_img,train_leb), (test_img, test_leb)= datasets.mnist.load_data()

# %%
train_img.shape[0]
# Out:
# 60000

# %%
# Check the shape of the whole training set
train_img.shape
# Out:
# (60000, 28, 28)

# %%
test_img.shape
# Out:
# (10000, 28, 28)

# %%
train_img = train_img.reshape((60000, 28, 28, 1)).astype('float32') / 255
test_img = test_img.reshape((10000, 28, 28, 1)).astype('float32') / 255

# %%
model = models.Sequential()

# %%
#  First Convolution Layer
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
# Out:
# C:\Users\dkglt\anaconda3\envs\torch310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# First Pooling Layer
model.add(layers.MaxPool2D((2,2)))

# %%
# Second Convolution Layera
model.add(layers.Conv2D(64,(3,3), activation='relu'))

# %%
# 2nd pooling lalaye
model.add(layers.MaxPool2D(2,2))

# %%
# 3rd convultion layer 
model.add(layers.Conv2D(64,(3,3), activation='relu'))

# %%
# add flattern feature map
model.add(layers.Flatten())

# %%
model.add(layers.Dense(64, activation='relu'))

# %%
model.add(layers.Dense(10, activation='softmax'))

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 3, 3, 64)       │        36,928 │
# ...

# %%
history = model.fit(train_img, train_leb, epochs=5, 
                    validation_data=(test_img, test_leb))
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 53s 27ms/step - accuracy: 0.8888 - loss: 0.3564 - val_accuracy: 0.9829 - val_loss: 0.0508
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 82s 26ms/step - accuracy: 0.9848 - loss: 0.0474 - val_accuracy: 0.9859 - val_loss: 0.0400
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 80s 25ms/step - accuracy: 0.9899 - loss: 0.0314 - val_accuracy: 0.9888 - val_loss: 0.0322
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 79s 24ms/step - accuracy: 0.9918 - loss: 0.0262 - val_accuracy: 0.9893 - val_loss: 0.0324
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 44s 24ms/step - accuracy: 0.9938 - loss: 0.0188 - val_accuracy: 0.9910 - val_loss: 0.0289

# %%
test_loss, test_acc = model.evaluate(test_img, test_leb, verbose=2)
print(f"Test accuracy: {test_acc*100:.2f}%")
# Out:
# 313/313 - 3s - 11ms/step - accuracy: 0.9910 - loss: 0.0289
# Test accuracy: 99.10%
